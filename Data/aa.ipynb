# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
df = pd.read_csv("/Users/joshsteinbecker/jts_project/Data/AminoAcid_Data.csv")
df
# Out:
#    letter three letter code      full name         R       Rank mass: gly  \
# 0       W               Trp     Tryptophan       NaN   1 (rank)  3.3x Gly
# 1       Y               Tyr       Tyrosine    -Ph-OH   2 (rank)  2.9x Gly
# 2       R               Arg       Arginine       NaN   3 (rank)  2.7x Gly
# 3       F               Phe  Phenylalanine       NaN   4 (rank)  2.6x Gly
# 4       H               His      Histidine       NaN   5 (rank)  2.4x Gly
# 5       M               Met     Methionine       NaN   6 (rank)  2.3x Gly
# 6       E               Glu  Glutamic Acid       NaN   7 (rank)  2.3x Gly
# 7       K               Lys         Lysine       NaN   8 (rank)  2.2x Gly
# 8       Q               Gln      Glutamine       NaN   9 (rank)  2.2x Gly
# 9       D               Asp  Aspartic Acid       NaN  10 (rank)  2.0x Gly
# 10      N               Asn     Asparagine       NaN  11 (rank)  2.0x Gly
# 11      I               Ile     Isoleucine       NaN  12 (rank)  2.0x Gly
# 12      L               Leu        Leucine  -C-C(C)C  12 (rank)  2.0x Gly
# 13      C               Cys       Cysteine       NaN  14 (rank)  1.8x Gly
# 14      T               Thr      Threonine       NaN  15 (rank)  1.8x Gly
# 15      V               Val         Valine       NaN  16 (rank)  1.7x Gly
# 16      P               Pro        Proline       NaN  17 (rank)  1.7x Gly
# 17      S               Ser         Serine       NaN  18 (rank)  1.5x Gly
# 18      A               Ala        Alanine       -Me  19 (rank)  1.2x Gly
# 19      G               Gly        Glycine        -H  20 (rank)  1.0x Gly
# 20      *               [*]           Stop       NaN        NaN       NaN
# 21      X               [X]        Unknown       NaN        NaN       NaN
#
#    composition  average mass    c    h    n basic Hydrophobic Polar
# 0    C11H10N2O        186.21  C11   H1   N2   NaN          HP   NaN
# 1      C9H9NO2        163.17   C9   H9  NaN   NaN         NaN     P
# 2     C6H12N4O        156.19   C6   H1   N4     B         NaN   NaN
# 3       C9H9NO        147.18   C9   H9  NaN   NaN          HP   NaN
# 4      C6H7N3O        137.14   C6   H7   N3     B         NaN   NaN
# 5      C5H9NOS        131.20   C5   H9  NaN   NaN          HP   NaN
# 6      C5H7NO3        129.12   C5   H7  NaN     A         NaN   NaN
# 7     C6H12N2O        128.17   C6   H1   N2     B         NaN   NaN
# 8     C5H8N2O2        128.13   C5   H8   N2   NaN         NaN   NaN
# 9      C4H5NO3        115.09   C4   H5  NaN     A         NaN   NaN
# 10    C4H6N2O2        114.10   C4   H6   N2   NaN         NaN   NaN
# 11     C6H11NO        113.16   C6   H1  NaN   NaN         NaN   NaN
# 12     C6H11NO        113.16   C6   H1  NaN   NaN         NaN   NaN
# 13     C3H5NOS        103.14   C3   H5  NaN   NaN         NaN   NaN
# 14     C4H7NO2        101.11   C4   H7  NaN   NaN         NaN     P
# 15      C5H9NO         99.13   C5   H9  NaN   NaN         NaN   NaN
# 16      C5H7NO         97.12   C5   H7  NaN   NaN         NaN   NaN
# 17     C3H5NO2         87.08   C3   H5  NaN   NaN         NaN     P
# 18      C3H5NO         71.08   C3   H5  NaN   NaN         NaN   NaN
# 19      C2H3NO         57.05   C2   H3  NaN   NaN          HP   NaN
# 20         NaN           NaN  NaN  NaN  NaN   NaN         NaN   NaN
# 21         NaN           NaN  NaN  NaN  NaN   NaN         NaN   NaN

# %%
df['nlen'] = [len(x) for x in df['full name']]
mass = df['average mass']

xyline = np.linspace(min(nlen),max(nlen),int(max(mass)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sz/0lyp_0wx3mgdzpg0t_hg1zh40000gn/T/ipykernel_3515/2710045732.py in <module>
#       2 mass = df['average mass']
#       3
# ----> 4 xyline = np.linspace(min(nlen),max(nlen),int(max(mass)))
#
# NameError: name 'nlen' is not defined

# %% [markdown]
# ## Section: Meaningless Correlations
# With the provided dataset, draw a correlation that has no use or causal relationships with each other.

# %%
plt.figure(figsize=(7,7))
plt.grid(linewidth = 0.6)
# plt.scatter(mass,nlen, c=df["letter"])
groups = df.groupby("letter")
for name, group in groups:
    plt.plot(group["average mass"],group["nlen"], marker="o", linestyle="", label=name,markersize=4)
    plt.annotate(name,(group["average mass"],group["nlen"]),fontsize=15,ha='right')
# for x,y in zip(df["average mass"],df["nlen"]):
#    label = f'{df["letter"]}'
#    plt.annotate(label,(df['average mass'],df['nlen']))
#plt.legend()
plt.plot(xyline,linestyle='--',color='black',alpha=0.4)
plt.xlabel('MASS OF RESIDUE')
plt.ylabel('LENGTH OF RESIDUE NAME')
plt.annotate('Name Suggests a Smaller than True Mass',(50,5))
plt.annotate('Name suggests a Larger than true Mass',(0,12))
plt.title('MASS VS NAME LENGTH OF AMINO ACIDS',fontsize=18)
plt.show()
